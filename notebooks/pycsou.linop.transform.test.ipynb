# %%
import sys
sys.path.append('..')
import numpy as np
import cupy as cp
import dask.array as da
import jax.numpy as jnp

# %%
from pycsou.linop.transform import FFTOp

for xp in [np, cp, da, jnp]:
    op= FFTOp()
    y = op(xp.arange(1000))
    print(y)
# Out:
# [499500.+0.00000000e+00j   -500.+1.59154419e+05j   -500.+7.95764243e+04j
#    -500.+5.30500769e+04j   -500.+3.97866414e+04j   -500.+3.18283706e+04j
#    -500.+2.65226822e+04j   -500.+2.27327551e+04j   -500.+1.98901789e+04j
#    -500.+1.76791699e+04j   -500.+1.59102580e+04j   -500.+1.44628711e+04j
#    -500.+1.32566281e+04j   -500.+1.22358804e+04j   -500.+1.13608789e+04j
#    -500.+1.06024744e+04j   -500.+9.93880495e+03j   -500.+9.35315260e+03j
#    -500.+8.83251450e+03j   -500.+8.36662521e+03j   -500.+7.94727242e+03j
#    -500.+7.56780805e+03j   -500.+7.22279275e+03j   -500.+6.90773317e+03j
#    -500.+6.61888483e+03j   -500.+6.35310237e+03j   -500.+6.10772434e+03j
#    -500.+5.88048357e+03j   -500.+5.66943678e+03j   -500.+5.47290871e+03j
#    -500.+5.28944750e+03j   -500.+5.11778859e+03j   -500.+4.95682551e+03j
#    -500.+4.80558591e+03j   -500.+4.66321182e+03j   -500.+4.52894334e+03j
#    -500.+4.40210499e+03j   -500.+4.28209432e+03j   -500.+4.16837229e+03j
# ...
